# %% [markdown]
# ## 1️⃣ AI / ML (Applied + Production Thinking)
#
# ### **Problem: Fraud Detection System**
#
# You’re building an ML system for **real-time transaction fraud detection**.
#
# ### **Dataset Schema**
#
# ```text
# transaction_id
# user_id
# transaction_time
# amount
# merchant_category
# device_type
# geo_location
# is_fraud (label)
# ```
#
# ### **Tasks**
#
# 1. What **features** would you engineer? (be specific)
# 2. How would you handle **class imbalance**?
# 3. Which model would you choose **and why**?
# 4. How would you evaluate the model **beyond accuracy**?
# 5. How would you deploy this in **low-latency production**?
# 6. How would you detect **model drift**?
#
# #### **Bonus**
#
# What would change if fraud patterns evolve **weekly**?
#
# #### **What I’m testing**
#
# * ML fundamentals
# * Trade-off thinking
# * Production readiness
# * Ability to think like an AI engineer, not a Kaggle player
#
# ---
#
# ## How to use this properly
#
# * Solve **one per day**
# * Write assumptions explicitly
# * Pretend this is an **interview or on-the-job task**
# * If you want, I can:
#
#   * Review your solution
#   * Increase difficulty
#   * Convert these into **mock interviews**
#   * Add **follow-up traps** like real interviewers do
